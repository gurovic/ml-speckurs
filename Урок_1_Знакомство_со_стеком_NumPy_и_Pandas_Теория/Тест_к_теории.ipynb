# %% [markdown]
# # Тест к теории (Занятие 1)
#
# 10 вопросов по теме занятия: Colab, текстовые ячейки, диалоговый режим, NumPy, `Series` и `DataFrame` в Pandas.

# %% [markdown]
# ---
# ### Вопрос 1. Из чего состоит ноутбук Colab?
#
# - A) из отдельных Python-файлов
# - B) из **ячеек** — кода и текста
# - C) из строк одной большой программы

# %% [markdown]
# ### Вопрос 2. Что напечатает эта ячейка?
#
# ```python
# import numpy as np
# a = np.array([1, 2, 3, 4])
# print((a * 2).sum())
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3. Что такое **векторизация** в NumPy?
#
# - A) применение операции сразу ко всем элементам массива без цикла
# - B) сортировка массива по возрастанию
# - C) перевод массива в вектор длины 1
# - D) хранение массива в памяти видеокарты

# %% [markdown]
# ### Вопрос 4. Какое свойство массива NumPy возвращает его **форму** — количество строк и столбцов?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 5. Дан код:
#
# ```python
# s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
# ```
#
# Что вернёт `s['b']`?
#
# - A) `10`
# - B) `'b'`
# - C) `[10, 20, 30]`
# - D) `20`
# - E) ошибку

# %% [markdown]
# ### Вопрос 6. Что напечатает эта ячейка?
#
# ```python
# import numpy as np
# m = np.array([[1, 2, 3, 4],
#               [5, 6, 7, 8]])
# print(m.sum())
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 7. Верно ли утверждение: «Переменная, созданная в одной ячейке ноутбука, доступна во всех следующих ячейках, пока среда не перезапущена»?
#
# - A) верно
# - B) неверно

# %% [markdown]
# ### Вопрос 8. Дан `DataFrame` с именем `df` и столбцом `'балл'`.
# Какое выражение вернёт этот столбец как `Series`?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 9. Что напечатает эта ячейка?
#
# ```python
# py_list = [1, 2, 3]
# print(py_list * 2)
# ```
#
# - A) `[2, 4, 6]`
# - B) `6`
# - C) `[1, 2, 3, 2, 4, 6]`
# - D) `[3, 6, 9]`
# - E) `[1, 2, 3, 1, 2, 3]`
# - F) ошибку

# %% [markdown]
# ### Вопрос 10. Как в Markdown записать заголовок **второго** уровня (подзаголовок)?
#
# - A) `**Заголовок**`
# - B) `# Заголовок`
# - C) `## Заголовок`
# - D) `> Заголовок`

# %% [markdown]
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | B |
# | 2 | открытый | `20` |
# | 3 | тест | A |
# | 4 | открытый | `shape` |
# | 5 | тест | D |
# | 6 | открытый | `36` |
# | 7 | тест | A |
# | 8 | открытый | `df['балл']` |
# | 9 | тест | E |
# | 10 | тест | C |
#
# **Как считать результат:** 1 балл за каждый верный ответ. 9–10 — отлично, 7–8 — хорошо,
# 5–6 — стоит повторить теорию, меньше 5 — вернитесь к материалам занятия.
