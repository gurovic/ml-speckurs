# %% [markdown]
# # Занятие 39. Упражнения: градиентный бустинг
#
# Короткая проверка теории (`gradient_boosting_theory.ipynb`, занятие 39). Сквозной код — в `gradient_boosting_practice.ipynb` (занятие 40).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Остатки (п. 6)
#
#
# Вычислите факт минус прогноз.

# %%
y=np.array([10.,15.,20.])
p=np.array([12.,12.,18.])
answer=...
assert np.array_equal(answer,[-2,3,2])
print('Верно')

# %% [markdown]
# ## 2. Один шаг (п. 4)
#
#
# Обновите прогноз при learning_rate=0.2.

# %%
old=np.array([10.,10.])
correction=np.array([-4.,6.])
new=...
assert np.allclose(new,[9.2,11.2])
print('Верно')

# %% [markdown]
# ## 3. Learning rate (п. 5)
#
#
# Маленький learning rate требует обычно больше или меньше деревьев?

# %%
answer=...
assert answer=='больше'
print('Верно')

# %% [markdown]
# ## 4. Bagging и boosting (п. 12)
#
#
# Где деревья последовательно исправляют ошибки?

# %%
answer=...
assert answer=='boosting'
print('Верно')

# %% [markdown]
# ## 5. Лучшая итерация (п. 2)
#
#
# Validation начала ухудшаться после 120 деревьев.

# %%
n_estimators=...
assert n_estimators==120
print('Верно')

# %% [markdown]
# ## 6. Early stopping (п. 8)
#
#
# Что он делает?

# %%
answer=...
assert answer=='останавливает без улучшения'
print('Верно')

# %% [markdown]
# ## 7. Глубина (п. 5)
#
#
# Что сильнее рискует переобучиться: 2 или 12?

# %%
depth=...
assert depth==12
print('Верно')

# %% [markdown]
# ## 8. Масштаб (п. 14)
#
#
# Обязательно ли масштабирование деревьям бустинга?

# %%
answer=...
assert answer is False
print('Верно')
