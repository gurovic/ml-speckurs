# %% [markdown]
# # Тест к теории (Занятие 13)
#
# Десять вопросов по теме занятия: расстояние, центроид, K-Means, дендрограмма, метод локтя.
# Часть вопросов — по картинкам. Правильные ответы — в таблице в конце.
#
# ---

# %% [markdown]
# ### Вопрос 1 (тест). Какое из утверждений о кластеризации верно?
#
# - A. Алгоритму заранее сообщают список групп, он лишь распределяет объекты.
# - B. Кластеризация — это обучение **без учителя**: группы выделяются по признакам самостоятельно.
# - C. Кластеризация работает только с двумя признаками.
# - D. Внутри одной группы объекты должны максимально **отличаться**.
# - E. Число объектов всегда равно числу групп.
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 2 (открытый, посчитать руками). Даны точки A = (0, 0) и B = (6, 8).
# Чему равно **евклидово** расстояние между ними?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3 (тест, по картинке). K-Means относит объект к **ближайшему** центру.
# К какому кластеру алгоритм отнесёт точку `P`?
#
# <img src="data:image/png;base64,..." />
#
# - A. К кластеру A
# - B. К кластеру B
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 4 (сопоставление). Соотнесите понятие с его смыслом.
#
# | Понятие | | Смысл |
# |---|---|---|
# | 1. Центроид | | A. Число групп, которое задаётся заранее |
# | 2. Инерция  | | B. Среднее группы по каждому признаку |
# | 3. K в K-Means | | C. Насколько компактно точки сидят вокруг центров |
#
# Формат ответа: `1-?, 2-?, 3-?`
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 5 (открытый, по картинке). На графике — кластер из трёх объектов.
# Чему равна координата **y** его центроида?
#
# <img src="data:image/png;base64,..." />
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 6 (тест, верно/неверно). Верно ли: в иерархической кластеризации число групп K нужно задавать **заранее**, как в K-Means?
#
# - A. Верно
# - B. Неверно
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 7 (открытый, посчитать руками). Группа состоит из трёх объектов с признаком «возраст»: 10, 20, 30.
# Чему равен центроид группы по этому признаку?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 8 (тест, по картинке). Дендрограмму разрезали горизонтально на высоте 5 (красная линия).
# Сколько групп получится после такого разреза?
#
# <img src="data:image/png;base64,..." />
#
# - A. 2
# - B. 3
# - C. 4
# - D. 8
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 9 (открытый, по картинке). По графику метода локтя определите, сколько кластеров
# разумнее всего взять для этих данных.
#
# <img src="data:image/png;base64,..." />
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 10 (сопоставление). Соотнесите функцию/метод с тем, что он делает.
#
# | Функция | | Что делает |
# |---|---|---|
# | 1. `linkage` | | A. Разрезает дерево на нужное число групп |
# | 2. `dendrogram` | | B. Считает порядок склеивания групп |
# | 3. `fcluster` | | C. Рисует дерево склеиваний |
#
# Формат ответа: `1-?, 2-?, 3-?`
#
# **Ответ:** _______

# %% [markdown]
# ---
# ### Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | B |
# | 2 | открытый | 10 |
# | 3 | тест (картинка) | B — до центра B ≈ 3.2, до центра A ≈ 4.2 |
# | 4 | сопоставление | 1-B, 2-C, 3-A |
# | 5 | открытый (картинка) | 3 — (2 + 2 + 5) / 3 |
# | 6 | тест | B (Неверно) |
# | 7 | открытый | 20 |
# | 8 | тест (картинка) | B — 3 группы |
# | 9 | открытый (картинка) | 4 — после K = 4 линия почти не убывает |
# | 10 | сопоставление | 1-B, 2-C, 3-A |
#
# **Как считать результат:** 9–10 — отлично; 7–8 — хорошо; 5–6 — стоит повторить тему; меньше 5 — вернуться к материалу занятия.
