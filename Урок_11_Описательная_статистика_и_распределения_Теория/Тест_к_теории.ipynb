# %% [markdown]
# # Тест к теории (Занятие 11)
#
# 10 вопросов по теме занятия: типы переменных, меры центра (`mean`, `median`, `mode`) и
# разброса (дисперсия, `std`, квантили, `IQR`), форма распределения (асимметрия, эксцесс),
# виды распределений, генеральная совокупность и выборка.

# %% [markdown]
# ---
# ### Вопрос 1 (тест, по картинке). Гистограмма показывает суммы заказов за день. Какая у распределения форма?
#
# <img src="data:image/png;base64,..." width="440"/>
#
# - A) симметричное
# - B) скошено вправо
# - C) скошено влево
# - D) равномерное

# %% [markdown]
# ### Вопрос 2 (открытый, по картинке). Каждая точка — один сотрудник поддержки, по горизонтали — сколько тикетов он закрыл за день. Чему равна **мода** (самое частое число закрытых тикетов)?
#
# <img src="data:image/png;base64,..." width="440"/>
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3 (сопоставление, по картинке). Три продуктовые метрики дали такие распределения. Соотнесите каждый график с типом распределения.
#
# <img src="data:image/png;base64,..." width="720"/>
#
# | № | График | Буква | Тип распределения |
# |---|---|---|---|
# | 1 | График 1 | A | нормальное («колокол») |
# | 2 | График 2 | B | логнормальное (скос вправо) |
# | 3 | График 3 | C | экспоненциальное (быстрый спад) |
#
# Запишите пары, например: `1-A, 2-B, 3-C`.

# %% [markdown]
# ### Вопрос 4 (тест). Верно ли: если среднее заметно **больше** медианы, распределение скошено **вправо**?
# - A) Верно
# - B) Неверно

# %% [markdown]
# ### Вопрос 5 (открытый, посчитать руками). Пять микросервисов за час обработали (тыс. запросов): **2, 4, 6, 8, 10**.
# Найдите **дисперсию** (среднее квадратов отклонений от среднего, делите на n = 5).
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 6 (тест). Какая мера центра **почти не меняется** от одного огромного выброса?
# - A) медиана
# - B) среднее
# - C) дисперсия
# - D) размах

# %% [markdown]
# ### Вопрос 7 (открытый, посчитать руками). Выручка девяти продуктов за месяц (тыс. руб), по порядку: **10, 20, 30, 40, 50, 60, 70, 80, 90**.
# Найдите **IQR** (`Q3 − Q1`), где `Q1` — квантиль 0.25 (3-е значение), `Q3` — квантиль 0.75 (7-е значение).
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 8 (тест, по картинке). Какому распределению соответствует эта гистограмма?
#
# <img src="data:image/png;base64,..." width="440"/>
#
# - A) экспоненциальное
# - B) логнормальное
# - C) нормальное

# %% [markdown]
# ### Вопрос 9 (сопоставление). Соотнесите меру с тем, что она показывает.
#
# | № | Мера | Буква | Что показывает |
# |---|---|---|---|
# | 1 | медиана | A | делит упорядоченный ряд пополам |
# | 2 | мода | B | средний разброс вокруг среднего |
# | 3 | IQR | C | самое частое значение |
# | 4 | стандартное отклонение | D | разброс центральной половины (`Q3 − Q1`) |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 10 (тест). Что показывает **стандартное отклонение**?
# - A) самое частое значение
# - B) насколько значения разбросаны вокруг среднего
# - C) медиану
# - D) число наблюдений

# %% [markdown]
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | B |
# | 2 | открытый | 20 |
# | 3 | сопоставление | 1-B, 2-A, 3-C |
# | 4 | тест | A — верно |
# | 5 | открытый | 8 |
# | 6 | тест | A |
# | 7 | открытый | 40 |
# | 8 | тест | C |
# | 9 | сопоставление | 1-A, 2-C, 3-D, 4-B |
# | 10 | тест | B |
#
# **Как считать результат:** 9–10 отлично; 7–8 хорошо; 5–6 стоит повторить;
# меньше 5 — вернуться к материалу занятия.
