# %% [markdown]
# # Занятие 33. Упражнения: переобучение и валидация
#
# Короткая проверка теории (`overfitting_validation_theory.ipynb`, занятие 33). Сквозной код — в `overfitting_validation_practice.ipynb` (занятие 34).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Диагноз (п. 1)
#
#
# Train accuracy 0,99, validation 0,68. Назовите состояние.

# %%
diagnosis=...
assert diagnosis=='переобучение'
print('Верно')

# %% [markdown]
# ## 2. Параметры (п. 4)
#
#
# Распределите коэффициенты и степень полинома.

# %%
parameter=...
hyperparameter=...
assert parameter=='коэффициенты' and hyperparameter=='степень полинома'
print('Верно')

# %% [markdown]
# ## 3. K-fold (п. 10)
#
#
# Сколько обучений для одного варианта при 5-fold?

# %%
fits=...
assert fits==5
print('Верно')

# %% [markdown]
# ## 4. Группы (п. 12)
#
#
# Какое разбиение выбрать для нескольких фото одного пациента?

# %%
splitter=...
assert splitter=='GroupKFold'
print('Верно')

# %% [markdown]
# ## 5. Время (п. 12)
#
#
# Можно ли перемешать будущие и прошлые продажи?

# %%
answer=...
assert answer is False
print('Верно')

# %% [markdown]
# ## 6. Fold preprocessing (п. 13)
#
#
# Где обучать scaler текущего fold?

# %%
part=...
assert part=='fold-train'
print('Верно')

# %% [markdown]
# ## 7. Validation curve (п. 8)
#
#
# На графике показана MSE: где выбирать сложность модели?

# %%
choice=...
assert choice=='минимум validation-ошибки'
print('Верно')

# %% [markdown]
# ## 8. Финальный fit (п. 17)
#
#
# На каких данных переобучить выбранный процесс перед test?

# %%
data=...
assert data=='train+validation'
print('Верно')
