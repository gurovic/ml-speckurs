# %% [markdown]
# # Занятие 10. Практика: визуализация — вопрос → ответ
#
# Короткая справка для проверки: по каждому заданию — что должно быть построено и какой
# вывод ожидается. Максимум — 30 баллов.

# %% [markdown]
# **Вопрос.** Задание 1 [2 балла]. Постройте **гистограмму** распределения сумм заказов (`amount`). Опишите форму распределения.

# %% [markdown]
# **Ответ:** правый скос, медиана ~4600, хвост до ~93000

# %% [markdown]
# **Вывод:** Распределение сильно скошено вправо: большинство заказов недорогие, но редкие крупные покупки тянут длинный правый хвост.

# %% [markdown]
# **Вопрос.** Задание 2 [2 балла]. Постройте **столбчатую диаграмму** числа заказов по категориям (`category`). Какая категория популярнее всех, какая реже всех?

# %% [markdown]
# **Ответ:** Одежда — максимум (277), Спорт — минимум (140)

# %% [markdown]
# **Вывод:** Больше всего заказов в категории «Одежда», меньше всего — в «Спорт»; спрос по категориям заметно неравномерен.

# %% [markdown]
# **Вопрос.** Задание 3 [2 балла]. Постройте **круговую диаграмму** долей заказов по устройствам (`device`); подпишите проценты на секторах. Какое устройство преобладает?

# %% [markdown]
# **Ответ:** Mobile ~52%, Desktop ~33%, Tablet ~15%

# %% [markdown]
# **Вывод:** Больше половины заказов делают с мобильных (~52%), примерно треть — с десктопа, планшеты — меньшинство.

# %% [markdown]
# **Вопрос.** Задание 4 [3 балла]. Сравните **средний чек по сегментам** клиентов (`segment`: New / Returning / VIP) столбчатой диаграммой. Во сколько примерно VIP дороже New?

# %% [markdown]
# **Ответ:** New~5890, Returning~7885, VIP~11086 (VIP/New ~1.9)

# %% [markdown]
# **Вывод:** Средний чек растёт от New к VIP: VIP тратят примерно в 1.9 раза больше, чем новые клиенты — сегмент действительно ценный.

# %% [markdown]
# **Вопрос.** Задание 5 [3 балла]. Постройте столбчатую диаграмму среднего чека **по категориям с разбивкой по сегментам** — столбцы одной категории раскрашены по сегменту (`segment`). В какой категории разрыв между VIP и New самый большой?

# %% [markdown]
# **Ответ:** макс. разрыв VIP-New — Электроника (~22000)

# %% [markdown]
# **Вывод:** Разрыв между VIP и New сильнее всего в «Электронике»: именно там VIP тратят кратно больше — дорогая техника делает сегмент особенно ценным.

# %% [markdown]
# **Вопрос.** Задание 6 [3 балла]. Постройте **линейный график** числа заказов по часам суток (`час`); часы по оси X должны идти по порядку от 0 до 23. В какие часы пик заказов?

# %% [markdown]
# **Ответ:** вечерний пик 18-21 (макс 20:00=155)

# %% [markdown]
# **Вывод:** Заказы концентрируются вечером: пик приходится на 18–21 час (максимум около 20:00), а ночью и ранним утром активность минимальна.

# %% [markdown]
# **Вопрос.** Задание 7 [4 балла]. Разбейте заказы на **две группы**: со скидкой и без (по столбцу `discount_pct`). Сравните группы по **среднему чеку** (`amount`) и **средней корзине** (`quantity`) — двумя столбчатыми графиками. Растёт ли корзина от скидок?

# %% [markdown]
# **Ответ:** чек со скидкой ниже (~7383 vs ~8465), корзина ~2.1 в обеих

# %% [markdown]
# **Вывод:** Скидки не увеличивают корзину: число товаров в заказе почти одинаковое, а средний чек со скидкой даже ниже — то есть скидки просто уменьшают выручку, а не стимулируют покупать больше.

# %% [markdown]
# **Вопрос.** Задание 8 [3 балла]. Постройте **тепловую карту** «город × категория»: по строкам — город, по столбцам — категория, в клетках — число заказов (подпишите числа в клетках). Какое сочетание город–категория самое «горячее»?

# %% [markdown]
# **Ответ:** горячая клетка Москва × Одежда (91)

# %% [markdown]
# **Вывод:** Самое «горячее» сочетание — Москва × Одежда (около 91 заказа): и заказов в Москве больше всех, и одежда — самая популярная категория.

# %% [markdown]
# **Вопрос.** Задание 9 [3 балла]. Постройте **тепловую карту** среднего чека «сегмент × категория»: по строкам — сегмент (`segment`), по столбцам — категория (`category`), в клетках — средний чек (`amount`); подпишите числа в клетках. В каком сочетании средний чек максимальный?

# %% [markdown]
# **Ответ:** горячая клетка VIP × Электроника (~38800)

# %% [markdown]
# **Вывод:** Самый высокий средний чек — у VIP в «Электронике» (~39 000): электроника дороже всех категорий, а VIP в каждой категории платят больше остальных сегментов.

# %% [markdown]
# **Вопрос.** Задание 10 [5 балла]. Соберите **портрет магазина на одном полотне**: сетка **2×2** из четырёх разных графиков. Например: выручка по каналам (`channel`), доли устройств (`device`), распределение сумм (`amount`), средний чек по сегментам (`segment`). В выводе опишите магазин 2–3 предложениями.

# %% [markdown]
# **Ответ:** 4 графика; Ads лидер по выручке, Mobile ~52%, скос сумм, VIP выше

# %% [markdown]
# **Вывод:** Магазин мобильный (более половины заказов с телефона) и «вечерний»; больше всего выручки приносит канал Ads; суммы заказов сильно скошены вправо, а самый ценный сегмент — VIP с заметно более высоким средним чеком.

# %% [markdown]
# ---
# ## Сводная таблица
#
# | № | Задание | Балл | Ключевое наблюдение |
# |---|---|---|---|
# | 1 | Распределение сумм (гистограмма) | 2 | правый скос, длинный хвост дорогих |
# | 2 | Заказы по категориям (столбцы) | 2 | Одежда — max (277), Спорт — min (140) |
# | 3 | Доли устройств (круговая) | 2 | Mobile ~52%, Desktop ~33%, Tablet ~15% |
# | 4 | Средний чек по сегментам | 3 | VIP ~1.9× дороже New |
# | 5 | Чек по категориям × сегмент (hue) | 3 | макс. разрыв VIP↔New — Электроника |
# | 6 | Заказы по часам (линия) | 3 | вечерний пик 18–21 (макс ~20:00) |
# | 7 | Скидка vs без: чек и корзина | 4 | корзина не растёт, чек со скидкой ниже |
# | 8 | Тепловая карта город × категория | 3 | горячая клетка — Москва × Одежда (91) |
# | 9 | Тепловая карта сегмент × категория (чек) | 3 | горячая клетка — VIP × Электроника (~38800) |
# | 10 | Портрет магазина (2×2) | 5 | Ads лидер, Mobile ~52%, скос сумм, VIP выше |
# | | **Итого** | **30** | |
