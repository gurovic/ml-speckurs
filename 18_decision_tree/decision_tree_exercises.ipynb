# %% [markdown]
# # Занятие 35. Упражнения: решающее дерево
#
# Короткая проверка теории (`decision_tree_theory.ipynb`, занятие 35). Сквозной код — в `decision_tree_practice.ipynb` (занятие 36).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Gini (п. 3)
#
#
# Найдите Gini двух равных классов.

# %%
answer=...
assert np.isclose(answer,.5)
print('Верно')

# %% [markdown]
# ## 2. Чистый узел (п. 3)
#
#
# Gini узла, где один класс.

# %%
answer=...
assert np.isclose(answer,0)
print('Верно')

# %% [markdown]
# ## 3. Разбиение (п. 4)
#
#
# Оба дочерних узла чистые. Найдите взвешенный Gini.

# %%
answer=...
assert np.isclose(answer,0)
print('Верно')

# %% [markdown]
# ## 4. Лист классификации (п. 8)
#
#
# В листе [1,1,1,0]. Найдите класс и долю класса 1.

# %%
pred=...
p1=...
assert pred==1 and np.isclose(p1,.75)
print('Верно')

# %% [markdown]
# ## 5. Лист регрессии (п. 7)
#
#
# Средний прогноз для [8,10,12].

# %%
answer=...
assert np.isclose(answer,10)
print('Верно')

# %% [markdown]
# ## 6. Глубина (п. 11)
#
#
# Какой параметр ограничивает глубину?

# %%
parameter=...
assert parameter=='max_depth'
print('Верно')

# %% [markdown]
# ## 7. Pruning (п. 11)
#
#
# Что происходит при росте ccp_alpha?

# %%
answer=...
assert answer=='дерево становится короче'
print('Верно')

# %% [markdown]
# ## 8. Масштаб (п. 12)
#
#
# Обязателен ли StandardScaler дереву?

# %%
answer=...
assert answer is False
print('Верно')
