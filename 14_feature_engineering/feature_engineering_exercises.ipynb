# %% [markdown]
# # Занятие 27. Упражнения: признаки
#
# Короткая проверка теории; полноценная практика будет на следующем занятии.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Безопасный признак
#
# Для прогноза цены выберите безопасный признак.

# %%
feature=...  # 'площадь на комнату' или 'цена за метр'
assert feature=='площадь на комнату'
print('Верно')

# %% [markdown]
# ## 2. Отношение
#
# Вычислите площадь на комнату.

# %%
area=np.array([30,60,90])
rooms=np.array([1,2,3])
answer=...
assert np.array_equal(answer,[30,30,30])
print('Верно')

# %% [markdown]
# ## 3. Логарифм
#
# Примените np.log1p.

# %%
income=np.array([0,100,10000])
answer=...
assert np.allclose(answer,np.log1p(income))
print('Верно')

# %% [markdown]
# ## 4. Дата
#
# Получите номера месяцев.

# %%
dates=pd.Series(pd.to_datetime(['2026-01-05','2026-07-02']))
months=...
assert list(months)==[1,7]
print('Верно')

# %% [markdown]
# ## 5. Unknown category
#
# Запишите полную настройку OneHotEncoder, безопасно обрабатывающую новую категорию, в виде строки handle_unknown='ignore'.

# %%
parameter=...
assert parameter=="handle_unknown='ignore'"
print('Верно')

# %% [markdown]
# ## 6. Пропуск
#
# Создайте индикатор пропуска.

# %%
values=pd.Series([2,np.nan,5,np.nan])
flag=...
assert np.array_equal(flag,[0,1,0,1])
print('Верно')

# %% [markdown]
# ## 7. Будущее
#
# Что нельзя включить в агрегат на 1 июня?

# %%
forbidden=...  # 'покупка 20 мая' или 'покупка 3 июня'
assert forbidden=='покупка 3 июня'
print('Верно')

# %% [markdown]
# ## 8. Проверка признака
#
# На какой части решают, оставить ли признак?

# %%
part=...
assert part=='validation'
print('Верно')
