# %% [markdown]
# # Тест к теории (Занятие 3)
#
# 10 коротких вопросов по теме занятия: булево маскирование, логические операторы `&` `|` `~`,
# метод `.query()`, `.copy()`, обработка пропусков (`.isna()`, `.dropna()`, `.fillna()`).
#
#
# ---
# ### Вопрос 1. Что вернёт выражение `df['балл_егэ'] > 80`?
# - A) `Series` из значений `True`/`False` для каждой строки — маску
# - B) число: сколько учеников с баллом больше 80
# - C) отфильтрованную таблицу с этими учениками
#
# ### Вопрос 2. Как правильно записать условие «девочки И сдали» булевой маской?
# - A) `df[df['пол'] == 'Ж' and df['сдал'] == 'да']`
# - B) `df[df['пол'] == 'Ж' & df['сдал'] == 'да']`
# - C) `df[(df['пол'] == 'Ж') & (df['сдал'] == 'да')]`
# - D) `df[df['пол'] == 'Ж', df['сдал'] == 'да']`
# - E) `df.filter(пол='Ж', сдал='да')`
#
# ### Вопрос 3. Что делает оператор `~` перед маской, например `df[~(df['город'] == 'Москва')]`?
# - A) сортирует таблицу по столбцу «город»
# - B) удаляет столбец «город»
# - C) считает количество строк из Москвы
# - D) переворачивает маску: оставляет строки, где условие НЕ выполняется
#
# ### Вопрос 4. Как через `.query()` записать «балл ЕГЭ выше 80 И пол — женский»?
# - A) `df.query(балл_егэ > 80 and пол == Ж)`
# - B) `df.query('балл_егэ > 80 and пол == "Ж"')`
# - C) `df.query('балл_егэ > 80 & пол == "Ж"')`
# - D) `df.query(df['балл_егэ'] > 80 and df['пол'] == 'Ж')`
#
# ### Вопрос 5. Зачем после фильтрации вызывают `.copy()`?
# - A) чтобы ускорить фильтрацию
# - B) чтобы удалить пропуски из результата
# - C) чтобы отсортировать строки
# - D) чтобы сохранить результат на диск
# - E) чтобы получить самостоятельную копию и безопасно её изменять — без `SettingWithCopyWarning`
# - F) вызывать вообще не обязательно, `.copy()` ничего не меняет
#
# ### Вопрос 6. Верно ли утверждение: «Если сделать `df.dropna()`, то из таблицы будут удалены все строки, в которых есть хотя бы один `NaN`»?
# - A) Верно
# - B) Неверно
#
# ---
#
# ### Вопрос 7. Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# s = pd.Series([10, 20, 30, 40, 50])
# mask = s > 20
# print(mask.sum())
# ```
#
# **Ответ:** _______
#
# ### Вопрос 8. Как называется метод, который возвращает маску `True`/`False`, где `True` стоит на месте пропусков?
#
# **Ответ:** _______
#
# ### Вопрос 9. Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# import numpy as np
# s = pd.Series([1, 2, np.nan, 4, np.nan, 6])
# print(s.dropna().sum())
# ```
#
# **Ответ:** _______
#
# ### Вопрос 10. Каким методом Pandas заполняют пропуски конкретным значением (например, средним по столбцу)?
#
# **Ответ:** _______
#
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | A |
# | 2 | тест | C |
# | 3 | тест | D |
# | 4 | тест | B |
# | 5 | тест | E |
# | 6 | верно/неверно | Верно (A) |
# | 7 | открытый | 2 |
# | 8 | открытый | `.isna()` (также принимается `.isnull()`) |
# | 9 | открытый | 13 |
# | 10 | открытый | `.fillna()` |
#
# **Как считать результат:** 9–10 отлично; 7–8 хорошо; 5–6 стоит повторить;
# меньше 5 — вернуться к материалу занятия.
