# %% [markdown]
# # Тест к теории (Занятие 7)
#
# 10 вопросов по теме занятия: `Timestamp` / `Timedelta`, `pd.to_datetime()` и аксессор
# `.dt`, интервалы между событиями, `value_counts()`, группировки `.groupby()` и сводные
# таблицы `pivot_table` / `crosstab`.

# %% [markdown]
# ---
# ### Вопрос 1 (тест). Что делает вызов `pd.to_datetime(df['created_at'])`?
# - A) возвращает столбец, преобразованный в тип `datetime64`
# - B) добавляет в `df` новый столбец с датами
# - C) меняет только формат отображения, а тип остаётся `object`
# - D) сортирует таблицу по дате

# %% [markdown]
# ### Вопрос 2 (открытый). Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# t1 = pd.Timestamp('2024-05-01')
# t2 = pd.Timestamp('2024-05-06')
# print((t2 - t1).days)
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3 (сопоставление). Соотнесите метод/атрибут с тем, что он возвращает.
#
# | № | Метод | Буква | Возвращает |
# |---|---|---|---|
# | 1 | `.dt.year` | A | название дня недели строкой («Monday») |
# | 2 | `.dt.dayofweek` | B | год числом |
# | 3 | `.dt.day_name()` | C | номер дня недели (0–6) |
# | 4 | `.dt.total_seconds()` | D | длину интервала в секундах |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 4 (тест). Верно ли: разность двух `Timestamp` (`t2 - t1`) снова даёт объект типа `Timestamp`?
# - A) Верно
# - B) Неверно

# %% [markdown]
# ### Вопрос 5 (открытый). Как называется аксессор, через который у столбца-даты достают компоненты (год, месяц, час, день недели)?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 6 (тест). Какой атрибут `.dt` возвращает **номер дня недели** (0 — понедельник, 6 — воскресенье)?
# - A) `.dt.day`
# - B) `.dt.day_name()`
# - C) `.dt.week`
# - D) `.dt.weekday_name`
# - E) `.dt.dayofweek`
# - F) `.dt.dow`

# %% [markdown]
# ### Вопрос 7 (сопоставление). Соотнесите функцию агрегации с тем, что она считает.
#
# | № | Функция | Буква | Считает |
# |---|---|---|---|
# | 1 | `'count'` | A | сумму значений |
# | 2 | `'sum'` | B | число значений в группе |
# | 3 | `'nunique'` | C | среднее |
# | 4 | `'mean'` | D | число **разных** значений |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 8 (тест). Что по умолчанию стоит в клетках результата `pd.crosstab(df['city'], df['payment'])`?
# - A) средний `amount`
# - B) сумма `amount`
# - C) доля в процентах
# - D) число заказов с таким сочетанием город–способ оплаты
# - E) список `order_id`

# %% [markdown]
# ### Вопрос 9 (открытый). Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# s = pd.Series([5, 5, 5, 8, 8, 1])
# print(s.value_counts().index[0])
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 10 (тест). Какой аргумент `pd.pivot_table()` задаёт, что окажется в **столбцах** сводной таблицы?
# - A) `index`
# - B) `values`
# - C) `columns`
# - D) `aggfunc`

# %% [markdown]
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | A |
# | 2 | открытый | 5 |
# | 3 | сопоставление | 1-B, 2-C, 3-A, 4-D |
# | 4 | тест | B — неверно, получается `Timedelta` |
# | 5 | открытый | `.dt` |
# | 6 | тест | E |
# | 7 | сопоставление | 1-B, 2-A, 3-D, 4-C |
# | 8 | тест | D |
# | 9 | открытый | 5 |
# | 10 | тест | C |
#
# **Как считать результат:** 9–10 отлично; 7–8 хорошо; 5–6 стоит повторить;
# меньше 5 — вернуться к материалу занятия.
