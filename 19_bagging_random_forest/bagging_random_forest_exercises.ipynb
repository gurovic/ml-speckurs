# %% [markdown]
# # Занятие 37. Упражнения: bagging и случайный лес
#
# Короткая проверка теории (`bagging_random_forest_theory.ipynb`, занятие 37). Сквозной код — в `bagging_random_forest_practice.ipynb` (занятие 38).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Bootstrap (п. 1)
#
#
# Может ли строка встретиться несколько раз?

# %%
answer=...
assert answer is True
print('Верно')

# %% [markdown]
# ## 2. OOB (п. 7)
#
#
# Как называются не попавшие в bootstrap объекты?

# %%
answer=...
assert answer=='OOB'
print('Верно')

# %% [markdown]
# ## 3. Среднее (п. 5)
#
#
# Усредните прогнозы.

# %%
p=np.array([70,75,80,75,70])
answer=...
assert np.isclose(answer,74)
print('Верно')

# %% [markdown]
# ## 4. Голосование (п. 5)
#
#
# Победитель [1,1,0,1,0].

# %%
answer=...
assert answer==1
print('Верно')

# %% [markdown]
# ## 5. Одинаковые ошибки (п. 6)
#
#
# Поможет ли усреднение одинаковых ошибок?

# %%
answer=...
assert answer is False
print('Верно')

# %% [markdown]
# ## 6. Случайный лес (п. 7)
#
#
# Что случайно выбирают в каждом узле?

# %%
answer=...
assert answer=='подмножество признаков'
print('Верно')

# %% [markdown]
# ## 7. Много деревьев (п. 9)
#
#
# После стабилизации качества новые деревья прежде всего...

# %%
answer=...
assert answer=='тратят ресурсы'
print('Верно')

# %% [markdown]
# ## 8. Importance (п. 14)
#
#
# Доказывает ли importance причинность?

# %%
answer=...
assert answer is False
print('Верно')
