# %% [markdown]
# # Тест к теории (Занятие 9)
#
# 10 вопросов по теме занятия: быстрые графики Pandas `.plot()` (`kind`, `bar`/`barh`,
# `hist`, `pie`, `scatter`), устройство Matplotlib (`Figure`, `Axes`, `plt.subplots()`,
# подписи и легенда) и разведочные графики Seaborn (`countplot`, `barplot`, `lineplot`,
# `histplot`, `scatterplot`, `heatmap`, параметр `hue`).

# %% [markdown]
# ---
# ### Вопрос 1 (тест). Что рисует метод `.plot()` без указания `kind`?
# - A) столбцы
# - B) линию
# - C) точки
# - D) круговую диаграмму

# %% [markdown]
# ### Вопрос 2 (открытый). Какое значение параметра `kind` в `.plot()` строит **горизонтальные** столбцы?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3 (тест). Что по умолчанию считает `sns.barplot(data=df, x='city', y='amount')` в каждой категории?
# - A) сумму
# - B) среднее
# - C) количество
# - D) медиану
# - E) максимум
# - F) минимум

# %% [markdown]
# ### Вопрос 4 (сопоставление). Соотнесите объект/команду Matplotlib с тем, что это.
#
# | № | Объект / команда | Буква | Что это |
# |---|---|---|---|
# | 1 | `Figure` | A | создаёт `Figure` и `Axes` |
# | 2 | `Axes` | B | всё полотно целиком |
# | 3 | `plt.subplots()` | C | область одного графика (оси, линии) |
# | 4 | `ax.legend()` | D | добавляет легенду |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 5 (тест). Какой метод возвращает частоты значений столбца, которые потом удобно строить столбцами?
# - A) `.groupby()`
# - B) `.describe()`
# - C) `.value_counts()`

# %% [markdown]
# ### Вопрос 6 (открытый). Какой параметр Seaborn-функций (`countplot`, `barplot`, `lineplot`) отвечает за разбивку и раскраску по второй категории?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 7 (тест). Верно ли: чтобы разместить несколько графиков в одной сетке на одном полотне, вызывают `plt.subplots(2, 2)`?
# - A) Верно
# - B) Неверно

# %% [markdown]
# ### Вопрос 8 (сопоставление). Соотнесите функцию Seaborn с тем, для чего она нужна.
#
# | № | Функция | Буква | Для чего |
# |---|---|---|---|
# | 1 | `countplot` | A | частота категорий |
# | 2 | `histplot` | B | матрица чисел цветом |
# | 3 | `scatterplot` | C | распределение числовой величины |
# | 4 | `heatmap` | D | связь двух числовых величин |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 9 (открытый). Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# s = pd.Series(['A', 'B', 'B', 'C', 'B', 'A'])
# print(s.value_counts().index[0])
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 10 (сопоставление). Соотнесите задачу анализа с подходящим типом графика.
#
# | № | Задача | Буква | График |
# |---|---|---|---|
# | 1 | динамика во времени | A | круговая (`pie`) |
# | 2 | доли целого | B | точечный (`scatter`) |
# | 3 | связь двух величин | C | линия (`line`) |
# | 4 | распределение одной величины | D | гистограмма (`hist`) |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | B |
# | 2 | открытый | `'barh'` |
# | 3 | тест | B |
# | 4 | сопоставление | 1-B, 2-C, 3-A, 4-D |
# | 5 | тест | C |
# | 6 | открытый | `hue` |
# | 7 | тест | A — верно |
# | 8 | сопоставление | 1-A, 2-C, 3-D, 4-B |
# | 9 | открытый | B |
# | 10 | сопоставление | 1-C, 2-A, 3-B, 4-D |
#
# **Как считать результат:** 9–10 отлично; 7–8 хорошо; 5–6 стоит повторить;
# меньше 5 — вернуться к материалу занятия.
