# %% [markdown]
# # Тест к теории (Занятие 5)
#
# 10 вопросов по теме занятия: работа со столбцами и строками (`.drop()`, `.rename()`),
# пользовательские функции через `.apply()` и `lambda`, строковый аксессор `.str`,
# объединение таблиц через `pd.concat()` и `pd.merge()` (типы соединений).

# %% [markdown]
# ---
# ### Вопрос 1 (тест). Что делает выражение `df.drop('источник_данных', axis=1)`?
# - A) возвращает новую таблицу без столбца `'источник_данных'`
# - B) удаляет строку с индексом `'источник_данных'`
# - C) возвращает новую таблицу, оставив только столбец `'источник_данных'`

# %% [markdown]
# ### Вопрос 2 (открытый). Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# s = pd.Series([1, 2, 3, 4])
# print(s.apply(lambda x: x * x).sum())
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 3 (сопоставление). Соотнесите тип соединения `merge` с тем, что он оставляет.
#
# | № | Тип | Буква | Что оставляет |
# |---|---|---|---|
# | 1 | `inner` | A | все строки левой таблицы |
# | 2 | `left` | B | только ключи, что есть в обеих таблицах |
# | 3 | `right` | C | все ключи из обеих таблиц |
# | 4 | `outer` | D | все строки правой таблицы |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 4 (тест). Как правильно создать через `.apply()` новый столбец `часов_в_день`, равный `часов_в_неделю / 7`?
# - A) `df['часов_в_день'] = df.apply(lambda x: x / 7, axis=1)`
# - B) `df['часов_в_день'] = df['часов_в_неделю'].apply(lambda x: x / 7)`
# - C) `df['часов_в_день'] = df['часов_в_неделю'].apply(x / 7)`
# - D) `df['часов_в_день'] = apply(df['часов_в_неделю'], lambda x: x / 7)`

# %% [markdown]
# ### Вопрос 5 (открытый). Как называется аксессор в Pandas, через который вызывают строковые методы у Series (например, `.upper()`, `.contains(...)`)?
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 6 (тест). Что вернёт выражение `df['город'].str.contains('Санкт')`?
# - A) число городов, содержащих «Санкт»
# - B) список названий городов, содержащих «Санкт»
# - C) новую таблицу только с этими городами
# - D) маску `True`/`False` — по одному значению на строку

# %% [markdown]
# ### Вопрос 7 (сопоставление). Соотнесите метод с тем, что он делает.
#
# | № | Метод | Буква | Что делает |
# |---|---|---|---|
# | 1 | `.drop(columns=...)` | A | применяет свою функцию к столбцу |
# | 2 | `.rename(columns=...)` | B | удаляет столбец |
# | 3 | `.apply(...)` | C | разбивает строку по разделителю |
# | 4 | `.str.split(...)` | D | переименовывает столбец |
#
# Запишите пары, например: `1-A, 2-B, 3-C, 4-D`.

# %% [markdown]
# ### Вопрос 8 (тест). Какой тип соединения `merge` оставит **только те строки, где ключ есть в ОБЕИХ таблицах**?
# - A) `left`
# - B) `right`
# - C) `inner`
# - D) `outer`
# - E) такого варианта нет — надо фильтровать после `merge`

# %% [markdown]
# ### Вопрос 9 (открытый). Что напечатает эта ячейка?
#
# ```python
# import pandas as pd
# left  = pd.DataFrame({'id': [1, 2, 3, 4], 'имя':   ['A', 'B', 'C', 'D']})
# right = pd.DataFrame({'id': [3, 4, 5, 6], 'город': ['X', 'Y', 'Z', 'W']})
# print(len(left.merge(right, on='id', how='inner')))
# ```
#
# **Ответ:** _______

# %% [markdown]
# ### Вопрос 10 (тест). Две таблицы с одинаковыми столбцами нужно поставить одну под другой (склеить «стопкой»). Что использовать?
# - A) `pd.merge(left, right)`
# - B) `pd.concat([a, b])`
# - C) `a.join(b)`
# - D) `a.apply(b)`

# %% [markdown]
# ---
# ## Правильные ответы
#
# | Вопрос | Тип | Ответ |
# |---|---|---|
# | 1 | тест | A |
# | 2 | открытый | 30 |
# | 3 | сопоставление | 1-B, 2-A, 3-D, 4-C |
# | 4 | тест | B |
# | 5 | открытый | `.str` |
# | 6 | тест | D |
# | 7 | сопоставление | 1-B, 2-D, 3-A, 4-C |
# | 8 | тест | C |
# | 9 | открытый | 2 |
# | 10 | тест | B |
#
# **Как считать результат:** 9–10 отлично; 7–8 хорошо; 5–6 стоит повторить;
# меньше 5 — вернуться к материалу занятия.
